# %% [markdown]
# # Ensemble Methods: VotingClassifier, StackingClassifier

# %% [markdown]
# Reminder: High bias implies an underfit model, high variance implies an overfit model.

# %% [markdown]
# ## First, a bagging method using a VotingClassifier will be used to reduce the amount of variance in the model. Then, a boosting method using a StackingClassifier will be run comparatively to reduce bias.

# %% [markdown]
# - ensemble averaging methods (VotingClassifier): average predictions to reduce variance.
# - ensemble boosting methods (StackingClassifier): base estimators are built sequentially and one tries to reduce the bias of the combined estimator.
# - Bagging methods work best with strong and complex models (e.g. where the data points are unpredictable), in contrast with boosting methods which usually work best with weak models (e.g., shallow decision trees).
# - Model with high bias pays very little attention to the training data and oversimplifies the model.
# - High variance models pays attention to training data and does not generalize on the data which it hasn’t seen before.

# %% [markdown]
# # VotingClassifier

# %%
# For model testing purposes, faster runtime for 455 row x 5 columns
from sklearn import datasets
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
warnings.filterwarnings(action='ignore', category=FutureWarning)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, log_loss
from yellowbrick.classifier import ClassificationReport
from mlxtend.evaluate import bias_variance_decomp
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import time
# from mlxtend.evaluate import bias_variance_decomp
# search = RandomizedSearchCV(ensemble_voting, ensemble_params, cv=3, n_iter=5)

# avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
#     ensemble_voting, X_train, y_train, X_test, y_test, 
#     loss='0-1_loss',
#     random_seed=123)

# print('Average expected loss: %.3f' % avg_expected_loss)
# print('Average bias: %.3f' % avg_bias)
# print('Average variance: %.3f' % avg_var)


iris = datasets.load_breast_cancer()
X = pd.DataFrame(iris.data[:, :5])  # we only take the first five features.
y = pd.DataFrame(iris.target)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(y_train[0].unique()) # binary classfication
X_train
# Out:
# [0 1]
#          0      1       2       3        4
# 38   14.99  25.20   95.54   698.8  0.09387
# 492  18.01  20.56  118.40  1007.0  0.10010
# 60   10.17  14.88   64.55   311.9  0.11340
# 440  10.97  17.20   71.73   371.5  0.08915
# 37   13.03  18.42   82.61   523.8  0.08983
# ..     ...    ...     ...     ...      ...
# 144  10.75  14.97   68.26   355.3  0.07793
# 355  12.56  19.07   81.92   485.8  0.08760
# 384  13.28  13.72   85.79   541.8  0.08363
# 329  16.26  21.88  107.50   826.8  0.11650
# 469  11.62  18.18   76.38   408.8  0.11750
#
# [455 rows x 5 columns]

# %%
def create_pipe_ensemble(X_train, ensemble_clf, clf_label='clf'):
    """
    https://medium.com/vickdata/a-simple-guide-to-scikit-learn-pipelines-4ac0d974bdcf
    Returns an sklearn model pipeline.
    """
    pipe = Pipeline([(clf_label, VotingClassifier(estimators=[
                          (clf_label+str(1), create_pipe(X_train, ensemble_clf.estimators[0][1])),
                          (clf_label+str(2), create_pipe(X_train, ensemble_clf.estimators[1][1])),
                          (clf_label+str(3), create_pipe(X_train, ensemble_clf.estimators[2][1])),
                          (clf_label+str(4), create_pipe(X_train, ensemble_clf.estimators[3][1])),
                          (clf_label+str(5), create_pipe(X_train, ensemble_clf.estimators[4][1])),
                          (clf_label+str(6), create_pipe(X_train, ensemble_clf.estimators[5][1])),
                          (clf_label+str(7), create_pipe(X_train, ensemble_clf.estimators[6][1])),
                          (clf_label+str(8), create_pipe(X_train, ensemble_clf.estimators[7][1]))
                                           ]))])
    return pipe

def clfy_report_ensemble(ensemble_voting, X_train, X_test, y_train, y_test, ensemble_params, cv=10):
    """
    Tune classifier hyperparameters and print metrics.
    """
    # Instantiate grid search using 10-fold cross validation:
    search = RandomizedSearchCV(ensemble_voting, ensemble_params, cv=cv, n_iter=5)
    
    # Learn relationship between predictors (basketball/tourney features) and outcome,
    # and the best parameters for defining such:
    search.fit(X_train, y_train)
    
    # Predictions on the test set, new data that haven't been introduced to the model:
    predicted = search.predict(X_test)
    
    # Predictions as probabilities:
    probabilities = search.predict_proba(X_test)[:, 1]
    
    # Accuracy scores for the training and test sets:
    train_accuracy = search.score(X_train, y_train)
    test_accuracy = search.score(X_test, y_test)

    print('Best Parameters: {}\n'.format(search.best_params_))
    print('Training Accuracy: {:0.2}'.format(train_accuracy))
    print('Test Accuracy: {:0.2}\n'.format(test_accuracy))
    
    # Confusion matrix labels:
    labels = np.array([['true losses','false wins'], ['false losses','true wins']])
    
    # Model evaluation metrics:
    confusion_mtrx = confusion_matrix(y_test, predicted)
    auc = roc_auc_score(y_test, probabilities)
    fpr, tpr, thresholds = roc_curve(y_test, probabilities)
    logloss = log_loss(y_test, search.predict_proba(X_test))
    
    # Plot all metrics in a grid of subplots:
    fig = plt.figure(figsize=(12, 12))
    grid = plt.GridSpec(2, 4, wspace=0.75, hspace=0.5)
    
    # Top-left plot - confusion matrix:
    plt.subplot(grid[0, :2])
    sns.heatmap(confusion_mtrx, annot=True, fmt="d") #, fmt='')
    plt.xlabel('Predicted Games')
    plt.ylabel('Actual Games');
    
    # Top-right plot - ROC curve:
    plt.subplot(grid[0, 2:])
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUROC: {:0.3}'.format(auc));
    
    # Bottom-left plot - support, or true predictions:
    plt.subplot(grid[1, :2])
    sns.countplot(y=predicted, orient='h')
    plt.yticks([1, 0], ('wins', 'losses'))
    plt.ylabel(''), plt.xlabel('Number Predicted');
    
    # Bottom-right plot - classification report:
    plt.subplot(grid[1, 2:])
    visualizer = ClassificationReport(search, classes=['losses', 'wins'])
    visualizer.fit(X_train, y_train)
    visualizer.score(X_test, y_test)
    g = visualizer.poof();
    
    return search, train_accuracy, test_accuracy, auc, logloss

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
numeric_features = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X_train.select_dtypes(include=['object']).columns
preprocessor = ColumnTransformer(
    transformers=[
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)])


classifiers = [
    SVC(probability=True),
    RandomForestClassifier(),
    LogisticRegression(),
    MLPClassifier(),
    GaussianNB(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    XGBClassifier()
    ]

pipeline_classifiers=[]
for i in range(0,len(classifiers)):
    pipeline_classifiers.append(Pipeline (steps=[('preprocessor', preprocessor),
        ('clf'+str(i+1), classifiers[i])]))

from sklearn.ensemble import VotingClassifier
ensemble_voting = Pipeline(steps=[('ensemble', VotingClassifier(estimators=[
    ('svc', pipeline_classifiers[0]), 
    ('rdf' , pipeline_classifiers[1]),
    ('lgr' , pipeline_classifiers[2]),
    ('mlp', pipeline_classifiers[3]),
    ('gau', pipeline_classifiers[4]),
    ('ada', pipeline_classifiers[5]), 
    ('gbt', pipeline_classifiers[6]),
    ('xgb', pipeline_classifiers[7])], 
                                voting='soft', 
                                # weights = [1,2,3], 
                                n_jobs=-1))])

import pprint as pp
pp.pprint(sorted(ensemble_voting.get_params().keys())) # used to specify ensemble params, below.
# Out:
# ['ensemble',
#  'ensemble__ada',
#  'ensemble__ada__clf6',
#  'ensemble__ada__clf6__algorithm',
#  'ensemble__ada__clf6__base_estimator',
#  'ensemble__ada__clf6__learning_rate',
#  'ensemble__ada__clf6__n_estimators',
#  'ensemble__ada__clf6__random_state',
#  'ensemble__ada__memory',
#  'ensemble__ada__preprocessor',
#  'ensemble__ada__preprocessor__cat',
#  'ensemble__ada__preprocessor__cat__imputer',
#  'ensemble__ada__preprocessor__cat__imputer__add_indicator',
#  'ensemble__ada__preprocessor__cat__imputer__copy',
#  'ensemble__ada__preprocessor__cat__imputer__fill_value',
#  'ensemble__ada__preprocessor__cat__imputer__missing_values',
#  'ensemble__ada__preprocessor__cat__imputer__strategy',
#  'ensemble__ada__preprocessor__cat__imputer__verbose',
#  'ensemble__ada__preprocessor__cat__memory',
#  'ensemble__ada__preprocessor__cat__onehot',
#  'ensemble__ada__preprocessor__cat__onehot__categories',
#  'ensemble__ada__preprocessor__cat__onehot__drop',
#  'ensemble__ada__preprocessor__cat__onehot__dtype',
#  'ensemble__ada__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__ada__preprocessor__cat__onehot__sparse',
#  'ensemble__ada__preprocessor__cat__steps',
#  'ensemble__ada__preprocessor__cat__verbose',
#  'ensemble__ada__preprocessor__n_jobs',
#  'ensemble__ada__preprocessor__num',
#  'ensemble__ada__preprocessor__num__imputer',
#  'ensemble__ada__preprocessor__num__imputer__add_indicator',
#  'ensemble__ada__preprocessor__num__imputer__copy',
#  'ensemble__ada__preprocessor__num__imputer__fill_value',
#  'ensemble__ada__preprocessor__num__imputer__missing_values',
#  'ensemble__ada__preprocessor__num__imputer__strategy',
#  'ensemble__ada__preprocessor__num__imputer__verbose',
#  'ensemble__ada__preprocessor__num__memory',
#  'ensemble__ada__preprocessor__num__scaler',
#  'ensemble__ada__preprocessor__num__scaler__copy',
#  'ensemble__ada__preprocessor__num__scaler__with_mean',
#  'ensemble__ada__preprocessor__num__scaler__with_std',
#  'ensemble__ada__preprocessor__num__steps',
#  'ensemble__ada__preprocessor__num__verbose',
#  'ensemble__ada__preprocessor__remainder',
#  'ensemble__ada__preprocessor__sparse_threshold',
#  'ensemble__ada__preprocessor__transformer_weights',
#  'ensemble__ada__preprocessor__transformers',
#  'ensemble__ada__preprocessor__verbose',
#  'ensemble__ada__steps',
#  'ensemble__ada__verbose',
#  'ensemble__estimators',
#  'ensemble__flatten_transform',
#  'ensemble__gau',
#  'ensemble__gau__clf5',
#  'ensemble__gau__clf5__priors',
#  'ensemble__gau__clf5__var_smoothing',
#  'ensemble__gau__memory',
#  'ensemble__gau__preprocessor',
#  'ensemble__gau__preprocessor__cat',
#  'ensemble__gau__preprocessor__cat__imputer',
#  'ensemble__gau__preprocessor__cat__imputer__add_indicator',
#  'ensemble__gau__preprocessor__cat__imputer__copy',
#  'ensemble__gau__preprocessor__cat__imputer__fill_value',
#  'ensemble__gau__preprocessor__cat__imputer__missing_values',
#  'ensemble__gau__preprocessor__cat__imputer__strategy',
#  'ensemble__gau__preprocessor__cat__imputer__verbose',
#  'ensemble__gau__preprocessor__cat__memory',
#  'ensemble__gau__preprocessor__cat__onehot',
#  'ensemble__gau__preprocessor__cat__onehot__categories',
#  'ensemble__gau__preprocessor__cat__onehot__drop',
#  'ensemble__gau__preprocessor__cat__onehot__dtype',
#  'ensemble__gau__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__gau__preprocessor__cat__onehot__sparse',
#  'ensemble__gau__preprocessor__cat__steps',
#  'ensemble__gau__preprocessor__cat__verbose',
#  'ensemble__gau__preprocessor__n_jobs',
#  'ensemble__gau__preprocessor__num',
#  'ensemble__gau__preprocessor__num__imputer',
#  'ensemble__gau__preprocessor__num__imputer__add_indicator',
#  'ensemble__gau__preprocessor__num__imputer__copy',
#  'ensemble__gau__preprocessor__num__imputer__fill_value',
#  'ensemble__gau__preprocessor__num__imputer__missing_values',
#  'ensemble__gau__preprocessor__num__imputer__strategy',
#  'ensemble__gau__preprocessor__num__imputer__verbose',
#  'ensemble__gau__preprocessor__num__memory',
#  'ensemble__gau__preprocessor__num__scaler',
#  'ensemble__gau__preprocessor__num__scaler__copy',
#  'ensemble__gau__preprocessor__num__scaler__with_mean',
#  'ensemble__gau__preprocessor__num__scaler__with_std',
#  'ensemble__gau__preprocessor__num__steps',
#  'ensemble__gau__preprocessor__num__verbose',
#  'ensemble__gau__preprocessor__remainder',
#  'ensemble__gau__preprocessor__sparse_threshold',
#  'ensemble__gau__preprocessor__transformer_weights',
#  'ensemble__gau__preprocessor__transformers',
#  'ensemble__gau__preprocessor__verbose',
#  'ensemble__gau__steps',
#  'ensemble__gau__verbose',
#  'ensemble__gbt',
#  'ensemble__gbt__clf7',
#  'ensemble__gbt__clf7__ccp_alpha',
#  'ensemble__gbt__clf7__criterion',
#  'ensemble__gbt__clf7__init',
#  'ensemble__gbt__clf7__learning_rate',
#  'ensemble__gbt__clf7__loss',
#  'ensemble__gbt__clf7__max_depth',
#  'ensemble__gbt__clf7__max_features',
#  'ensemble__gbt__clf7__max_leaf_nodes',
#  'ensemble__gbt__clf7__min_impurity_decrease',
#  'ensemble__gbt__clf7__min_impurity_split',
#  'ensemble__gbt__clf7__min_samples_leaf',
#  'ensemble__gbt__clf7__min_samples_split',
#  'ensemble__gbt__clf7__min_weight_fraction_leaf',
#  'ensemble__gbt__clf7__n_estimators',
#  'ensemble__gbt__clf7__n_iter_no_change',
#  'ensemble__gbt__clf7__presort',
#  'ensemble__gbt__clf7__random_state',
#  'ensemble__gbt__clf7__subsample',
#  'ensemble__gbt__clf7__tol',
#  'ensemble__gbt__clf7__validation_fraction',
#  'ensemble__gbt__clf7__verbose',
#  'ensemble__gbt__clf7__warm_start',
#  'ensemble__gbt__memory',
#  'ensemble__gbt__preprocessor',
#  'ensemble__gbt__preprocessor__cat',
#  'ensemble__gbt__preprocessor__cat__imputer',
#  'ensemble__gbt__preprocessor__cat__imputer__add_indicator',
#  'ensemble__gbt__preprocessor__cat__imputer__copy',
#  'ensemble__gbt__preprocessor__cat__imputer__fill_value',
#  'ensemble__gbt__preprocessor__cat__imputer__missing_values',
#  'ensemble__gbt__preprocessor__cat__imputer__strategy',
#  'ensemble__gbt__preprocessor__cat__imputer__verbose',
#  'ensemble__gbt__preprocessor__cat__memory',
#  'ensemble__gbt__preprocessor__cat__onehot',
#  'ensemble__gbt__preprocessor__cat__onehot__categories',
#  'ensemble__gbt__preprocessor__cat__onehot__drop',
#  'ensemble__gbt__preprocessor__cat__onehot__dtype',
#  'ensemble__gbt__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__gbt__preprocessor__cat__onehot__sparse',
#  'ensemble__gbt__preprocessor__cat__steps',
#  'ensemble__gbt__preprocessor__cat__verbose',
#  'ensemble__gbt__preprocessor__n_jobs',
#  'ensemble__gbt__preprocessor__num',
#  'ensemble__gbt__preprocessor__num__imputer',
#  'ensemble__gbt__preprocessor__num__imputer__add_indicator',
#  'ensemble__gbt__preprocessor__num__imputer__copy',
#  'ensemble__gbt__preprocessor__num__imputer__fill_value',
#  'ensemble__gbt__preprocessor__num__imputer__missing_values',
#  'ensemble__gbt__preprocessor__num__imputer__strategy',
#  'ensemble__gbt__preprocessor__num__imputer__verbose',
#  'ensemble__gbt__preprocessor__num__memory',
#  'ensemble__gbt__preprocessor__num__scaler',
#  'ensemble__gbt__preprocessor__num__scaler__copy',
#  'ensemble__gbt__preprocessor__num__scaler__with_mean',
#  'ensemble__gbt__preprocessor__num__scaler__with_std',
#  'ensemble__gbt__preprocessor__num__steps',
#  'ensemble__gbt__preprocessor__num__verbose',
#  'ensemble__gbt__preprocessor__remainder',
#  'ensemble__gbt__preprocessor__sparse_threshold',
#  'ensemble__gbt__preprocessor__transformer_weights',
#  'ensemble__gbt__preprocessor__transformers',
#  'ensemble__gbt__preprocessor__verbose',
#  'ensemble__gbt__steps',
#  'ensemble__gbt__verbose',
#  'ensemble__lgr',
#  'ensemble__lgr__clf3',
#  'ensemble__lgr__clf3__C',
#  'ensemble__lgr__clf3__class_weight',
#  'ensemble__lgr__clf3__dual',
#  'ensemble__lgr__clf3__fit_intercept',
#  'ensemble__lgr__clf3__intercept_scaling',
#  'ensemble__lgr__clf3__l1_ratio',
#  'ensemble__lgr__clf3__max_iter',
#  'ensemble__lgr__clf3__multi_class',
#  'ensemble__lgr__clf3__n_jobs',
#  'ensemble__lgr__clf3__penalty',
#  'ensemble__lgr__clf3__random_state',
#  'ensemble__lgr__clf3__solver',
#  'ensemble__lgr__clf3__tol',
#  'ensemble__lgr__clf3__verbose',
#  'ensemble__lgr__clf3__warm_start',
#  'ensemble__lgr__memory',
#  'ensemble__lgr__preprocessor',
#  'ensemble__lgr__preprocessor__cat',
#  'ensemble__lgr__preprocessor__cat__imputer',
#  'ensemble__lgr__preprocessor__cat__imputer__add_indicator',
#  'ensemble__lgr__preprocessor__cat__imputer__copy',
#  'ensemble__lgr__preprocessor__cat__imputer__fill_value',
#  'ensemble__lgr__preprocessor__cat__imputer__missing_values',
#  'ensemble__lgr__preprocessor__cat__imputer__strategy',
#  'ensemble__lgr__preprocessor__cat__imputer__verbose',
#  'ensemble__lgr__preprocessor__cat__memory',
#  'ensemble__lgr__preprocessor__cat__onehot',
#  'ensemble__lgr__preprocessor__cat__onehot__categories',
#  'ensemble__lgr__preprocessor__cat__onehot__drop',
#  'ensemble__lgr__preprocessor__cat__onehot__dtype',
#  'ensemble__lgr__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__lgr__preprocessor__cat__onehot__sparse',
#  'ensemble__lgr__preprocessor__cat__steps',
#  'ensemble__lgr__preprocessor__cat__verbose',
#  'ensemble__lgr__preprocessor__n_jobs',
#  'ensemble__lgr__preprocessor__num',
#  'ensemble__lgr__preprocessor__num__imputer',
#  'ensemble__lgr__preprocessor__num__imputer__add_indicator',
#  'ensemble__lgr__preprocessor__num__imputer__copy',
#  'ensemble__lgr__preprocessor__num__imputer__fill_value',
#  'ensemble__lgr__preprocessor__num__imputer__missing_values',
#  'ensemble__lgr__preprocessor__num__imputer__strategy',
#  'ensemble__lgr__preprocessor__num__imputer__verbose',
#  'ensemble__lgr__preprocessor__num__memory',
#  'ensemble__lgr__preprocessor__num__scaler',
#  'ensemble__lgr__preprocessor__num__scaler__copy',
#  'ensemble__lgr__preprocessor__num__scaler__with_mean',
#  'ensemble__lgr__preprocessor__num__scaler__with_std',
#  'ensemble__lgr__preprocessor__num__steps',
#  'ensemble__lgr__preprocessor__num__verbose',
#  'ensemble__lgr__preprocessor__remainder',
#  'ensemble__lgr__preprocessor__sparse_threshold',
#  'ensemble__lgr__preprocessor__transformer_weights',
#  'ensemble__lgr__preprocessor__transformers',
#  'ensemble__lgr__preprocessor__verbose',
#  'ensemble__lgr__steps',
#  'ensemble__lgr__verbose',
#  'ensemble__mlp',
#  'ensemble__mlp__clf4',
#  'ensemble__mlp__clf4__activation',
#  'ensemble__mlp__clf4__alpha',
#  'ensemble__mlp__clf4__batch_size',
#  'ensemble__mlp__clf4__beta_1',
#  'ensemble__mlp__clf4__beta_2',
#  'ensemble__mlp__clf4__early_stopping',
#  'ensemble__mlp__clf4__epsilon',
#  'ensemble__mlp__clf4__hidden_layer_sizes',
#  'ensemble__mlp__clf4__learning_rate',
#  'ensemble__mlp__clf4__learning_rate_init',
#  'ensemble__mlp__clf4__max_fun',
#  'ensemble__mlp__clf4__max_iter',
#  'ensemble__mlp__clf4__momentum',
#  'ensemble__mlp__clf4__n_iter_no_change',
#  'ensemble__mlp__clf4__nesterovs_momentum',
#  'ensemble__mlp__clf4__power_t',
#  'ensemble__mlp__clf4__random_state',
#  'ensemble__mlp__clf4__shuffle',
#  'ensemble__mlp__clf4__solver',
#  'ensemble__mlp__clf4__tol',
#  'ensemble__mlp__clf4__validation_fraction',
#  'ensemble__mlp__clf4__verbose',
#  'ensemble__mlp__clf4__warm_start',
#  'ensemble__mlp__memory',
#  'ensemble__mlp__preprocessor',
#  'ensemble__mlp__preprocessor__cat',
#  'ensemble__mlp__preprocessor__cat__imputer',
#  'ensemble__mlp__preprocessor__cat__imputer__add_indicator',
#  'ensemble__mlp__preprocessor__cat__imputer__copy',
#  'ensemble__mlp__preprocessor__cat__imputer__fill_value',
#  'ensemble__mlp__preprocessor__cat__imputer__missing_values',
#  'ensemble__mlp__preprocessor__cat__imputer__strategy',
#  'ensemble__mlp__preprocessor__cat__imputer__verbose',
#  'ensemble__mlp__preprocessor__cat__memory',
#  'ensemble__mlp__preprocessor__cat__onehot',
#  'ensemble__mlp__preprocessor__cat__onehot__categories',
#  'ensemble__mlp__preprocessor__cat__onehot__drop',
#  'ensemble__mlp__preprocessor__cat__onehot__dtype',
#  'ensemble__mlp__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__mlp__preprocessor__cat__onehot__sparse',
#  'ensemble__mlp__preprocessor__cat__steps',
#  'ensemble__mlp__preprocessor__cat__verbose',
#  'ensemble__mlp__preprocessor__n_jobs',
#  'ensemble__mlp__preprocessor__num',
#  'ensemble__mlp__preprocessor__num__imputer',
#  'ensemble__mlp__preprocessor__num__imputer__add_indicator',
#  'ensemble__mlp__preprocessor__num__imputer__copy',
#  'ensemble__mlp__preprocessor__num__imputer__fill_value',
#  'ensemble__mlp__preprocessor__num__imputer__missing_values',
#  'ensemble__mlp__preprocessor__num__imputer__strategy',
#  'ensemble__mlp__preprocessor__num__imputer__verbose',
#  'ensemble__mlp__preprocessor__num__memory',
#  'ensemble__mlp__preprocessor__num__scaler',
#  'ensemble__mlp__preprocessor__num__scaler__copy',
#  'ensemble__mlp__preprocessor__num__scaler__with_mean',
#  'ensemble__mlp__preprocessor__num__scaler__with_std',
#  'ensemble__mlp__preprocessor__num__steps',
#  'ensemble__mlp__preprocessor__num__verbose',
#  'ensemble__mlp__preprocessor__remainder',
#  'ensemble__mlp__preprocessor__sparse_threshold',
#  'ensemble__mlp__preprocessor__transformer_weights',
#  'ensemble__mlp__preprocessor__transformers',
#  'ensemble__mlp__preprocessor__verbose',
#  'ensemble__mlp__steps',
#  'ensemble__mlp__verbose',
#  'ensemble__n_jobs',
#  'ensemble__rdf',
#  'ensemble__rdf__clf2',
#  'ensemble__rdf__clf2__bootstrap',
#  'ensemble__rdf__clf2__ccp_alpha',
#  'ensemble__rdf__clf2__class_weight',
#  'ensemble__rdf__clf2__criterion',
#  'ensemble__rdf__clf2__max_depth',
#  'ensemble__rdf__clf2__max_features',
#  'ensemble__rdf__clf2__max_leaf_nodes',
#  'ensemble__rdf__clf2__max_samples',
#  'ensemble__rdf__clf2__min_impurity_decrease',
#  'ensemble__rdf__clf2__min_impurity_split',
#  'ensemble__rdf__clf2__min_samples_leaf',
#  'ensemble__rdf__clf2__min_samples_split',
#  'ensemble__rdf__clf2__min_weight_fraction_leaf',
#  'ensemble__rdf__clf2__n_estimators',
#  'ensemble__rdf__clf2__n_jobs',
#  'ensemble__rdf__clf2__oob_score',
#  'ensemble__rdf__clf2__random_state',
#  'ensemble__rdf__clf2__verbose',
#  'ensemble__rdf__clf2__warm_start',
#  'ensemble__rdf__memory',
#  'ensemble__rdf__preprocessor',
#  'ensemble__rdf__preprocessor__cat',
#  'ensemble__rdf__preprocessor__cat__imputer',
#  'ensemble__rdf__preprocessor__cat__imputer__add_indicator',
#  'ensemble__rdf__preprocessor__cat__imputer__copy',
#  'ensemble__rdf__preprocessor__cat__imputer__fill_value',
#  'ensemble__rdf__preprocessor__cat__imputer__missing_values',
#  'ensemble__rdf__preprocessor__cat__imputer__strategy',
#  'ensemble__rdf__preprocessor__cat__imputer__verbose',
#  'ensemble__rdf__preprocessor__cat__memory',
#  'ensemble__rdf__preprocessor__cat__onehot',
#  'ensemble__rdf__preprocessor__cat__onehot__categories',
#  'ensemble__rdf__preprocessor__cat__onehot__drop',
#  'ensemble__rdf__preprocessor__cat__onehot__dtype',
#  'ensemble__rdf__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__rdf__preprocessor__cat__onehot__sparse',
#  'ensemble__rdf__preprocessor__cat__steps',
#  'ensemble__rdf__preprocessor__cat__verbose',
#  'ensemble__rdf__preprocessor__n_jobs',
#  'ensemble__rdf__preprocessor__num',
#  'ensemble__rdf__preprocessor__num__imputer',
#  'ensemble__rdf__preprocessor__num__imputer__add_indicator',
#  'ensemble__rdf__preprocessor__num__imputer__copy',
#  'ensemble__rdf__preprocessor__num__imputer__fill_value',
#  'ensemble__rdf__preprocessor__num__imputer__missing_values',
#  'ensemble__rdf__preprocessor__num__imputer__strategy',
#  'ensemble__rdf__preprocessor__num__imputer__verbose',
#  'ensemble__rdf__preprocessor__num__memory',
#  'ensemble__rdf__preprocessor__num__scaler',
#  'ensemble__rdf__preprocessor__num__scaler__copy',
#  'ensemble__rdf__preprocessor__num__scaler__with_mean',
#  'ensemble__rdf__preprocessor__num__scaler__with_std',
#  'ensemble__rdf__preprocessor__num__steps',
#  'ensemble__rdf__preprocessor__num__verbose',
#  'ensemble__rdf__preprocessor__remainder',
#  'ensemble__rdf__preprocessor__sparse_threshold',
#  'ensemble__rdf__preprocessor__transformer_weights',
#  'ensemble__rdf__preprocessor__transformers',
#  'ensemble__rdf__preprocessor__verbose',
#  'ensemble__rdf__steps',
#  'ensemble__rdf__verbose',
#  'ensemble__svc',
#  'ensemble__svc__clf1',
#  'ensemble__svc__clf1__C',
#  'ensemble__svc__clf1__break_ties',
#  'ensemble__svc__clf1__cache_size',
#  'ensemble__svc__clf1__class_weight',
#  'ensemble__svc__clf1__coef0',
#  'ensemble__svc__clf1__decision_function_shape',
#  'ensemble__svc__clf1__degree',
#  'ensemble__svc__clf1__gamma',
#  'ensemble__svc__clf1__kernel',
#  'ensemble__svc__clf1__max_iter',
#  'ensemble__svc__clf1__probability',
#  'ensemble__svc__clf1__random_state',
#  'ensemble__svc__clf1__shrinking',
#  'ensemble__svc__clf1__tol',
#  'ensemble__svc__clf1__verbose',
#  'ensemble__svc__memory',
#  'ensemble__svc__preprocessor',
#  'ensemble__svc__preprocessor__cat',
#  'ensemble__svc__preprocessor__cat__imputer',
#  'ensemble__svc__preprocessor__cat__imputer__add_indicator',
#  'ensemble__svc__preprocessor__cat__imputer__copy',
#  'ensemble__svc__preprocessor__cat__imputer__fill_value',
#  'ensemble__svc__preprocessor__cat__imputer__missing_values',
#  'ensemble__svc__preprocessor__cat__imputer__strategy',
#  'ensemble__svc__preprocessor__cat__imputer__verbose',
#  'ensemble__svc__preprocessor__cat__memory',
#  'ensemble__svc__preprocessor__cat__onehot',
#  'ensemble__svc__preprocessor__cat__onehot__categories',
#  'ensemble__svc__preprocessor__cat__onehot__drop',
#  'ensemble__svc__preprocessor__cat__onehot__dtype',
#  'ensemble__svc__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__svc__preprocessor__cat__onehot__sparse',
#  'ensemble__svc__preprocessor__cat__steps',
#  'ensemble__svc__preprocessor__cat__verbose',
#  'ensemble__svc__preprocessor__n_jobs',
#  'ensemble__svc__preprocessor__num',
#  'ensemble__svc__preprocessor__num__imputer',
#  'ensemble__svc__preprocessor__num__imputer__add_indicator',
#  'ensemble__svc__preprocessor__num__imputer__copy',
#  'ensemble__svc__preprocessor__num__imputer__fill_value',
#  'ensemble__svc__preprocessor__num__imputer__missing_values',
#  'ensemble__svc__preprocessor__num__imputer__strategy',
#  'ensemble__svc__preprocessor__num__imputer__verbose',
#  'ensemble__svc__preprocessor__num__memory',
#  'ensemble__svc__preprocessor__num__scaler',
#  'ensemble__svc__preprocessor__num__scaler__copy',
#  'ensemble__svc__preprocessor__num__scaler__with_mean',
#  'ensemble__svc__preprocessor__num__scaler__with_std',
#  'ensemble__svc__preprocessor__num__steps',
#  'ensemble__svc__preprocessor__num__verbose',
#  'ensemble__svc__preprocessor__remainder',
#  'ensemble__svc__preprocessor__sparse_threshold',
#  'ensemble__svc__preprocessor__transformer_weights',
#  'ensemble__svc__preprocessor__transformers',
#  'ensemble__svc__preprocessor__verbose',
#  'ensemble__svc__steps',
#  'ensemble__svc__verbose',
#  'ensemble__voting',
#  'ensemble__weights',
#  'ensemble__xgb',
#  'ensemble__xgb__clf8',
#  'ensemble__xgb__clf8__base_score',
#  'ensemble__xgb__clf8__booster',
#  'ensemble__xgb__clf8__colsample_bylevel',
#  'ensemble__xgb__clf8__colsample_bynode',
#  'ensemble__xgb__clf8__colsample_bytree',
#  'ensemble__xgb__clf8__gamma',
#  'ensemble__xgb__clf8__learning_rate',
#  'ensemble__xgb__clf8__max_delta_step',
#  'ensemble__xgb__clf8__max_depth',
#  'ensemble__xgb__clf8__min_child_weight',
#  'ensemble__xgb__clf8__missing',
#  'ensemble__xgb__clf8__n_estimators',
#  'ensemble__xgb__clf8__n_jobs',
#  'ensemble__xgb__clf8__nthread',
#  'ensemble__xgb__clf8__objective',
#  'ensemble__xgb__clf8__random_state',
#  'ensemble__xgb__clf8__reg_alpha',
#  'ensemble__xgb__clf8__reg_lambda',
#  'ensemble__xgb__clf8__scale_pos_weight',
#  'ensemble__xgb__clf8__seed',
#  'ensemble__xgb__clf8__silent',
#  'ensemble__xgb__clf8__subsample',
#  'ensemble__xgb__clf8__verbosity',
#  'ensemble__xgb__memory',
#  'ensemble__xgb__preprocessor',
#  'ensemble__xgb__preprocessor__cat',
#  'ensemble__xgb__preprocessor__cat__imputer',
#  'ensemble__xgb__preprocessor__cat__imputer__add_indicator',
#  'ensemble__xgb__preprocessor__cat__imputer__copy',
#  'ensemble__xgb__preprocessor__cat__imputer__fill_value',
#  'ensemble__xgb__preprocessor__cat__imputer__missing_values',
#  'ensemble__xgb__preprocessor__cat__imputer__strategy',
#  'ensemble__xgb__preprocessor__cat__imputer__verbose',
#  'ensemble__xgb__preprocessor__cat__memory',
#  'ensemble__xgb__preprocessor__cat__onehot',
#  'ensemble__xgb__preprocessor__cat__onehot__categories',
#  'ensemble__xgb__preprocessor__cat__onehot__drop',
#  'ensemble__xgb__preprocessor__cat__onehot__dtype',
#  'ensemble__xgb__preprocessor__cat__onehot__handle_unknown',
#  'ensemble__xgb__preprocessor__cat__onehot__sparse',
#  'ensemble__xgb__preprocessor__cat__steps',
#  'ensemble__xgb__preprocessor__cat__verbose',
#  'ensemble__xgb__preprocessor__n_jobs',
#  'ensemble__xgb__preprocessor__num',
#  'ensemble__xgb__preprocessor__num__imputer',
#  'ensemble__xgb__preprocessor__num__imputer__add_indicator',
#  'ensemble__xgb__preprocessor__num__imputer__copy',
#  'ensemble__xgb__preprocessor__num__imputer__fill_value',
#  'ensemble__xgb__preprocessor__num__imputer__missing_values',
#  'ensemble__xgb__preprocessor__num__imputer__strategy',
#  'ensemble__xgb__preprocessor__num__imputer__verbose',
#  'ensemble__xgb__preprocessor__num__memory',
#  'ensemble__xgb__preprocessor__num__scaler',
#  'ensemble__xgb__preprocessor__num__scaler__copy',
#  'ensemble__xgb__preprocessor__num__scaler__with_mean',
#  'ensemble__xgb__preprocessor__num__scaler__with_std',
#  'ensemble__xgb__preprocessor__num__steps',
#  'ensemble__xgb__preprocessor__num__verbose',
#  'ensemble__xgb__preprocessor__remainder',
#  'ensemble__xgb__preprocessor__sparse_threshold',
#  'ensemble__xgb__preprocessor__transformer_weights',
#  'ensemble__xgb__preprocessor__transformers',
#  'ensemble__xgb__preprocessor__verbose',
#  'ensemble__xgb__steps',
#  'ensemble__xgb__verbose',
#  'memory',
#  'steps',
#  'verbose']

# %%
ensemble_params=[
    { # SVC
        'ensemble__svc__clf1__kernel': ['rbf', 'linear', 'sigmoid'],
        'ensemble__svc__clf1__C': np.logspace(start=-10, stop=10, num=21) # default 1.0
    },
    { # RandomForestClassifier
        'ensemble__rdf__clf2__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'ensemble__rdf__clf2__max_features': ['sqrt', 'log2'] # The lower the greater the reduction of variance, but also the greater the increase in bias.
    },
    { # LogisticRegression
        'ensemble__lgr__clf3__C': np.logspace(start=-10, stop=10, num=21),
        'ensemble__lgr__clf3__penalty': ['none', 'l2']
    },
    { # Neural network multi-layered perceptron, MLPClassifier
      'ensemble__mlp__clf4__hidden_layer_sizes': tuple(map(tuple, np.random.randint(low=5, high=20, size=(10, 3)))) # from 5-20 nodes per 3 layers, 10 iterations
    },
    { # GaussianNB
        'ensemble__gau__clf5__var_smoothing': [1e-8, 1e-9, 1e-10]
    },
    { # AdaBoostClassifier
        'ensemble__ada__clf6__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'ensemble__ada__clf6__learning_rate': np.linspace(0.5, 1.5, 10, endpoint=True) # default 1.0
    },
    { # GradientBoostingClassifier
        'ensemble__gbt__clf7__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'ensemble__gbt__clf7__learning_rate': np.linspace(0.02, 0.18, 9, endpoint=True) # default 0.1
    },
    { # XGBClassifier
#     'clf__learning_rate': np.logspace(start=0.01, stop=0.2, num=10, endpoint = True), # see last example in np.logspace documentation
    'ensemble__xgb__clf8__max_depth': [2,3,4,5],
    'ensemble__xgb__clf8__booster': ['gbtree', 'gblinear', 'dart']
    }
]
timer_start=time.time()
clfy_report_ensemble(ensemble_voting, X_train, X_test, y_train, y_test, ensemble_params, cv=3)
# Out:
# Best Parameters: {'ensemble__xgb__clf8__max_depth': 3, 'ensemble__xgb__clf8__booster': 'dart'}
#
# Training Accuracy: 0.96
# Test Accuracy: 0.94
# (RandomizedSearchCV(cv=3, error_score=nan,
#                     estimator=Pipeline(memory=None,
#                                        steps=[('ensemble',
#                                                VotingClassifier(estimators=[('svc',
#                                                                              Pipeline(memory=None,
#                                                                                       steps=[('preprocessor',
#                                                                                               ColumnTransformer(n_jobs=None,
#                                                                                                                 remainder='drop',
#                                                                                                                 sparse_threshold=0.3,
#                                                                                                                 transformer_weights=None,
#                                                                                                                 transformers=[('num',
#                                                                                                                                Pipeline(memory=None,
#                                                                                                                                         steps=[('imputer',
#                                                                                                                                                 SimpleImputer(add_indicator...
#                                          {'ensemble__gbt__clf7__learning_rate': array([0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18]),
#                                           'ensemble__gbt__clf7__n_estimators': array([100, 111, 122, 133, 144, 155, 166, 177, 188, 200])},
#                                          {'ensemble__xgb__clf8__booster': ['gbtree',
#                                                                            'gblinear',
#                                                                            'dart'],
#                                           'ensemble__xgb__clf8__max_depth': [2,
#                                                                              3,
#                                                                              4,
#                                                                              5]}],
#                     pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                     return_train_score=False, scoring=None, verbose=0),
#  0.964824120603015,
#  0.935672514619883,
#  0.9916764018691588,
#  0.16845396615245437)

# %%
print("Time taken:", round(timer_start-time.time(),2),'seconds. ')
del timer_start
# Out:
# Time taken: -60.71 seconds.

# %% [markdown]
# # StackingClassifier

# %%
classifiers = [
    ('svc',  SVC(probability=True)       ),
    ('rdf' , RandomForestClassifier()    ),
    ('lgr' , LogisticRegression()        ),
    ('mlp',  MLPClassifier()             ),
    ('gau',  GaussianNB()                ),
    ('ada',  AdaBoostClassifier()        ),
    ('gbt',  GradientBoostingClassifier()),
    ('xgb',  XGBClassifier()             )   
    ]

from sklearn.ensemble import StackingClassifier
stack_clf = StackingClassifier(estimators=classifiers, final_estimator=LogisticRegression())
pipe_stack_clf = Pipeline(steps=[('preproc', preprocessor), ('stack', stack_clf)])

# %%
pp.pprint(sorted(pipe_stack_clf.get_params().keys())) # used to specify pipe_stack_clf params, below.
# Out:
# ['memory',
#  'preproc',
#  'preproc__cat',
#  'preproc__cat__imputer',
#  'preproc__cat__imputer__add_indicator',
#  'preproc__cat__imputer__copy',
#  'preproc__cat__imputer__fill_value',
#  'preproc__cat__imputer__missing_values',
#  'preproc__cat__imputer__strategy',
#  'preproc__cat__imputer__verbose',
#  'preproc__cat__memory',
#  'preproc__cat__onehot',
#  'preproc__cat__onehot__categories',
#  'preproc__cat__onehot__drop',
#  'preproc__cat__onehot__dtype',
#  'preproc__cat__onehot__handle_unknown',
#  'preproc__cat__onehot__sparse',
#  'preproc__cat__steps',
#  'preproc__cat__verbose',
#  'preproc__n_jobs',
#  'preproc__num',
#  'preproc__num__imputer',
#  'preproc__num__imputer__add_indicator',
#  'preproc__num__imputer__copy',
#  'preproc__num__imputer__fill_value',
#  'preproc__num__imputer__missing_values',
#  'preproc__num__imputer__strategy',
#  'preproc__num__imputer__verbose',
#  'preproc__num__memory',
#  'preproc__num__scaler',
#  'preproc__num__scaler__copy',
#  'preproc__num__scaler__with_mean',
#  'preproc__num__scaler__with_std',
#  'preproc__num__steps',
#  'preproc__num__verbose',
#  'preproc__remainder',
#  'preproc__sparse_threshold',
#  'preproc__transformer_weights',
#  'preproc__transformers',
#  'preproc__verbose',
#  'stack',
#  'stack__ada',
#  'stack__ada__algorithm',
#  'stack__ada__base_estimator',
#  'stack__ada__learning_rate',
#  'stack__ada__n_estimators',
#  'stack__ada__random_state',
#  'stack__cv',
#  'stack__estimators',
#  'stack__final_estimator',
#  'stack__final_estimator__C',
#  'stack__final_estimator__class_weight',
#  'stack__final_estimator__dual',
#  'stack__final_estimator__fit_intercept',
#  'stack__final_estimator__intercept_scaling',
#  'stack__final_estimator__l1_ratio',
#  'stack__final_estimator__max_iter',
#  'stack__final_estimator__multi_class',
#  'stack__final_estimator__n_jobs',
#  'stack__final_estimator__penalty',
#  'stack__final_estimator__random_state',
#  'stack__final_estimator__solver',
#  'stack__final_estimator__tol',
#  'stack__final_estimator__verbose',
#  'stack__final_estimator__warm_start',
#  'stack__gau',
#  'stack__gau__priors',
#  'stack__gau__var_smoothing',
#  'stack__gbt',
#  'stack__gbt__ccp_alpha',
#  'stack__gbt__criterion',
#  'stack__gbt__init',
#  'stack__gbt__learning_rate',
#  'stack__gbt__loss',
#  'stack__gbt__max_depth',
#  'stack__gbt__max_features',
#  'stack__gbt__max_leaf_nodes',
#  'stack__gbt__min_impurity_decrease',
#  'stack__gbt__min_impurity_split',
#  'stack__gbt__min_samples_leaf',
#  'stack__gbt__min_samples_split',
#  'stack__gbt__min_weight_fraction_leaf',
#  'stack__gbt__n_estimators',
#  'stack__gbt__n_iter_no_change',
#  'stack__gbt__presort',
#  'stack__gbt__random_state',
#  'stack__gbt__subsample',
#  'stack__gbt__tol',
#  'stack__gbt__validation_fraction',
#  'stack__gbt__verbose',
#  'stack__gbt__warm_start',
#  'stack__lgr',
#  'stack__lgr__C',
#  'stack__lgr__class_weight',
#  'stack__lgr__dual',
#  'stack__lgr__fit_intercept',
#  'stack__lgr__intercept_scaling',
#  'stack__lgr__l1_ratio',
#  'stack__lgr__max_iter',
#  'stack__lgr__multi_class',
#  'stack__lgr__n_jobs',
#  'stack__lgr__penalty',
#  'stack__lgr__random_state',
#  'stack__lgr__solver',
#  'stack__lgr__tol',
#  'stack__lgr__verbose',
#  'stack__lgr__warm_start',
#  'stack__mlp',
#  'stack__mlp__activation',
#  'stack__mlp__alpha',
#  'stack__mlp__batch_size',
#  'stack__mlp__beta_1',
#  'stack__mlp__beta_2',
#  'stack__mlp__early_stopping',
#  'stack__mlp__epsilon',
#  'stack__mlp__hidden_layer_sizes',
#  'stack__mlp__learning_rate',
#  'stack__mlp__learning_rate_init',
#  'stack__mlp__max_fun',
#  'stack__mlp__max_iter',
#  'stack__mlp__momentum',
#  'stack__mlp__n_iter_no_change',
#  'stack__mlp__nesterovs_momentum',
#  'stack__mlp__power_t',
#  'stack__mlp__random_state',
#  'stack__mlp__shuffle',
#  'stack__mlp__solver',
#  'stack__mlp__tol',
#  'stack__mlp__validation_fraction',
#  'stack__mlp__verbose',
#  'stack__mlp__warm_start',
#  'stack__n_jobs',
#  'stack__passthrough',
#  'stack__rdf',
#  'stack__rdf__bootstrap',
#  'stack__rdf__ccp_alpha',
#  'stack__rdf__class_weight',
#  'stack__rdf__criterion',
#  'stack__rdf__max_depth',
#  'stack__rdf__max_features',
#  'stack__rdf__max_leaf_nodes',
#  'stack__rdf__max_samples',
#  'stack__rdf__min_impurity_decrease',
#  'stack__rdf__min_impurity_split',
#  'stack__rdf__min_samples_leaf',
#  'stack__rdf__min_samples_split',
#  'stack__rdf__min_weight_fraction_leaf',
#  'stack__rdf__n_estimators',
#  'stack__rdf__n_jobs',
#  'stack__rdf__oob_score',
#  'stack__rdf__random_state',
#  'stack__rdf__verbose',
#  'stack__rdf__warm_start',
#  'stack__stack_method',
#  'stack__svc',
#  'stack__svc__C',
#  'stack__svc__break_ties',
#  'stack__svc__cache_size',
#  'stack__svc__class_weight',
#  'stack__svc__coef0',
#  'stack__svc__decision_function_shape',
#  'stack__svc__degree',
#  'stack__svc__gamma',
#  'stack__svc__kernel',
#  'stack__svc__max_iter',
#  'stack__svc__probability',
#  'stack__svc__random_state',
#  'stack__svc__shrinking',
#  'stack__svc__tol',
#  'stack__svc__verbose',
#  'stack__verbose',
#  'stack__xgb',
#  'stack__xgb__base_score',
#  'stack__xgb__booster',
#  'stack__xgb__colsample_bylevel',
#  'stack__xgb__colsample_bynode',
#  'stack__xgb__colsample_bytree',
#  'stack__xgb__gamma',
#  'stack__xgb__learning_rate',
#  'stack__xgb__max_delta_step',
#  'stack__xgb__max_depth',
#  'stack__xgb__min_child_weight',
#  'stack__xgb__missing',
#  'stack__xgb__n_estimators',
#  'stack__xgb__n_jobs',
#  'stack__xgb__nthread',
#  'stack__xgb__objective',
#  'stack__xgb__random_state',
#  'stack__xgb__reg_alpha',
#  'stack__xgb__reg_lambda',
#  'stack__xgb__scale_pos_weight',
#  'stack__xgb__seed',
#  'stack__xgb__silent',
#  'stack__xgb__subsample',
#  'stack__xgb__verbosity',
#  'steps',
#  'verbose']

# %%
pipe_stack_clf_params=[
    { # SVC
        'stack__svc__kernel': ['rbf', 'linear', 'sigmoid'],
        'stack__svc__C': np.logspace(start=-10, stop=10, num=21) # default 1.0
    },
    { # RandomForestClassifier
        'stack__rdf__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'stack__rdf__max_features': ['sqrt', 'log2'] # The lower the greater the reduction of variance, but also the greater the increase in bias.
    },
    { # LogisticRegression
        'stack__lgr__C': np.logspace(start=-10, stop=10, num=21),
        'stack__lgr__penalty': ['none', 'l2']
    },
    { # Neural network multi-layered perceptron, MLPClassifier
        'stack__mlp__hidden_layer_sizes': tuple(map(tuple, np.random.randint(low=5, high=20, size=(10, 3)))) # from 5-20 nodes per 3 layers, 10 iterations
    },
    { # GaussianNB
        'stack__gau__var_smoothing': [1e-8, 1e-9, 1e-10]
    },
    { # AdaBoostClassifier
        'stack__ada__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'stack__ada__learning_rate': np.linspace(0.5, 1.5, 10, endpoint=True) # default 1.0
    },
    { # GradientBoostingClassifier
        'stack__gbt__n_estimators': np.array(np.linspace(100,200,10, endpoint=True) , dtype=np.int32), # default 100
        'stack__gbt__learning_rate': np.linspace(0.02, 0.18, 9, endpoint=True) # default 0.1
    },
    { # XGBClassifier
#     'clf__learning_rate': np.logspace(start=0.01, stop=0.2, num=10, endpoint = True), # see last example in np.logspace documentation
        'stack__xgb__max_depth': [2,3,4,5],
        'stack__xgb__booster': ['gbtree', 'gblinear', 'dart']
    }
]
# print(search, train_accuracy, test_accuracy, auc, logloss)
clfy_report_ensemble(pipe_stack_clf, X_train, X_test, y_train, y_test, pipe_stack_clf_params, cv=3)
# Out:
# Best Parameters: {'stack__ada__n_estimators': 100, 'stack__ada__learning_rate': 1.1666666666666665}
#
# Training Accuracy: 0.96
# Test Accuracy: 0.94
# (RandomizedSearchCV(cv=3, error_score=nan,
#                     estimator=Pipeline(memory=None,
#                                        steps=[('preproc',
#                                                ColumnTransformer(n_jobs=None,
#                                                                  remainder='drop',
#                                                                  sparse_threshold=0.3,
#                                                                  transformer_weights=None,
#                                                                  transformers=[('num',
#                                                                                 Pipeline(memory=None,
#                                                                                          steps=[('imputer',
#                                                                                                  SimpleImputer(add_indicator=False,
#                                                                                                                copy=True,
#                                                                                                                fill_value=None,
#                                                                                                                missing_values=nan,
#                                                                                                                strategy='median',
#                                                                                                                verbose=0))...
#                                           'stack__ada__n_estimators': array([100, 111, 122, 133, 144, 155, 166, 177, 188, 200])},
#                                          {'stack__gbt__learning_rate': array([0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18]),
#                                           'stack__gbt__n_estimators': array([100, 111, 122, 133, 144, 155, 166, 177, 188, 200])},
#                                          {'stack__xgb__booster': ['gbtree',
#                                                                   'gblinear',
#                                                                   'dart'],
#                                           'stack__xgb__max_depth': [2, 3, 4,
#                                                                     5]}],
#                     pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                     return_train_score=False, scoring=None, verbose=0),
#  0.9597989949748744,
#  0.9415204678362573,
#  0.9926985981308412,
#  0.13453682092861183)

# %% [markdown]
# ## StackedClassifier loss, bias, variance

# %%
avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        stack_clf, np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test), 
        loss='0-1_loss',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
# Out:
# Average expected loss: 0.467
# Average bias: 79.339
# Average variance: 0.039

# %% [markdown]
# ## VotingClassifier loss, bias, variance

# %%
ensemble_voting[0]
# Out:
# VotingClassifier(estimators=[('svc',
#                               Pipeline(memory=None,
#                                        steps=[('preprocessor',
#                                                ColumnTransformer(n_jobs=None,
#                                                                  remainder='drop',
#                                                                  sparse_threshold=0.3,
#                                                                  transformer_weights=None,
#                                                                  transformers=[('num',
#                                                                                 Pipeline(memory=None,
#                                                                                          steps=[('imputer',
#                                                                                                  SimpleImputer(add_indicator=False,
#                                                                                                                copy=True,
#                                                                                                                fill_value=None,
#                                                                                                                missing_values=nan,
#                                                                                                                strategy='median',
#                                                                                                                verbose=0)),
#                                                                                                 ('scaler...
#                                                              colsample_bytree=1,
#                                                              gamma=0,
#                                                              learning_rate=0.1,
#                                                              max_delta_step=0,
#                                                              max_depth=3,
#                                                              min_child_weight=1,
#                                                              missing=None,
#                                                              n_estimators=100,
#                                                              n_jobs=1,
#                                                              nthread=None,
#                                                              objective='binary:logistic',
#                                                              random_state=0,
#                                                              reg_alpha=0,
#                                                              reg_lambda=1,
#                                                              scale_pos_weight=1,
#                                                              seed=None,
#                                                              silent=None,
#                                                              subsample=1,
#                                                              verbosity=1))],
#                                        verbose=False))],
#                  flatten_transform=True, n_jobs=-1, voting='soft',
#                  weights=None)

# %%
avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        ensemble_voting[0], np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test), 
        loss='0-1_loss',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
# Out:
# Average expected loss: 0.464
# Average bias: 79.088
# Average variance: 0.022

# %% [markdown]
# - ensemble averaging methods (VotingClassifier): average predictions to reduce variance.
# - ensemble boosting methods (StackingClassifier): base estimators are built sequentially and one tries to reduce the bias of the combined estimator.
# - Bagging methods work best with strong and complex models (e.g. where the data points are unpredictable), in contrast with boosting methods which usually work best with weak models (e.g., shallow decision trees).
# - Model with high bias pays very little attention to the training data and oversimplifies the model.
# - High variance models pays attention to training data and does not generalize on the data which it hasn’t seen before.

# %% [markdown]
# #### From these results, the models built have very low variance, low loss, and very high bias. This implies that the final model needs to use the StackingClassifier.
